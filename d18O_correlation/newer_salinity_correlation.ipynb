# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the unified dataset
df = pd.read_csv("unified_datasets.csv")
df["month"] = pd.to_datetime(df["month"].astype(str))  # convert Period to datetime for plotting
df = df.dropna()

# Plot each column
plt.figure(figsize=(12, 6))
for col in df.columns:
    if col != "month":
        plt.plot(df["month"], df[col], label=col)

plt.title("Unified Monthly Time Series")
plt.xlabel("Month")
plt.ylabel("Value")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
import seaborn as sns

# Supplementary Salinity Data
correlation_matrix = df[['d18O', 'sst', 'sup_salinity']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %%
# Multiple Linear Regression
X = df[['sst', 'sup_salinity']]
y = df['d18O']
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled = sm.add_constant(X_scaled)
model = sm.OLS(y, X_scaled).fit()
print(model.summary())

# Visualize
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

axs[0].scatter(df['sst'], df['d18O'], color='blue')
sns.regplot(x='sst', y='d18O', data=df, scatter=False, ax=axs[0], color='blue', line_kws={'label': 'Best Fit Line'})
axs[0].legend()
axs[0].set_title("SST vs d18O")
axs[0].set_xlabel("SST")
axs[0].set_ylabel("d18O")

axs[1].scatter(df['sup_salinity'], df['d18O'], color='green')
sns.regplot(x='sup_salinity', y='d18O', data=df, scatter=False, ax=axs[1], color='green', line_kws={'label': 'Best Fit Line'})
axs[1].legend()
axs[1].set_title("Supplementary Salinity vs d18O")
axs[1].set_xlabel("Supplementary Salinity")
axs[1].set_ylabel("d18O")

plt.tight_layout()
plt.show()
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   d18O   R-squared:                       0.513
# Model:                            OLS   Adj. R-squared:                  0.504
# Method:                 Least Squares   F-statistic:                     58.96
# Date:                Tue, 15 Jul 2025   Prob (F-statistic):           3.23e-18
# Time:                        10:14:37   Log-Likelihood:                 10.530
# No. Observations:                 115   AIC:                            -15.06
# Df Residuals:                     112   BIC:                            -6.824
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.7810      0.021   -181.225      0.000      -3.822      -3.740
# x1            -0.2277      0.021    -10.854      0.000      -0.269      -0.186
# x2             0.0303      0.021      1.443      0.152      -0.011       0.072
# ==============================================================================
# Omnibus:                        0.164   Durbin-Watson:                   0.549
# Prob(Omnibus):                  0.921   Jarque-Bera (JB):                0.295
# Skew:                           0.077   Prob(JB):                        0.863
# Kurtosis:                       2.805   Cond. No.                         1.11
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /var/folders/8v/z7_lynrn24bbpwy6p36j3cwc0000gn/T/ipykernel_54132/2111641947.py:15: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[0].legend()
# /var/folders/8v/z7_lynrn24bbpwy6p36j3cwc0000gn/T/ipykernel_54132/2111641947.py:22: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[1].legend()

# %%
X_sst = sm.add_constant(df['sst'])
model_sst = sm.OLS(df['d18O'], X_sst).fit()
print("R² for SST only:", model_sst.rsquared)

X_salinity = sm.add_constant(df['sup_salinity'])
model_salinity = sm.OLS(df['d18O'], X_salinity).fit()
print("R² for Salinity only:", model_salinity.rsquared)
# Out:
# R² for SST only: 0.5037979808299236
# R² for Salinity only: 0.000464800201296911

# %% [markdown]
# # Results
#
# **Statistically significant** negative correlation between SST and d18O.
# - Pearson correlation of $-0.71$.
# - Slope coefficient of $-0.2178$.
# - $p < 0.001$.
#
# Statistically *in*significant negative correlation between SSS (sup) and d18O.
# - Pearson correlation of $0.022$.
# - Slope coefficient of $0.0303$.
# - $p = 0.152 > 0.05$.

# %%
# Create lagged features for aux salinity
dataframes = {}
for i in range(-5, 6):
    if i != 0:
        copy = df.copy()
        copy['sup_salinity'] = df['sup_salinity'].shift(-i).fillna(method='ffill')
        copy = copy.dropna(subset=['d18O', 'sst', 'sup_salinity'])
        dataframes[i] = copy
# Out:
# /var/folders/8v/z7_lynrn24bbpwy6p36j3cwc0000gn/T/ipykernel_54132/3749082753.py:6: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   copy['sup_salinity'] = df['sup_salinity'].shift(-i).fillna(method='ffill')

# %%
# Graph the lagged features on the same plot
for i in range(-5, 6):
    if i == 0:
        lagged_df = df
    else:
        lagged_df = dataframes[i]
    plt.figure(figsize=(12, 6))
    for col in df.columns:
        if col != "month":
            plt.plot(lagged_df["month"], lagged_df[col], label=col)
    
    plt.title("Unified Monthly Time Series (Lagged Salinity " + str(i) + " months)")
    plt.xlabel("Month")
    plt.ylabel("Value")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
plt.show()

# %%
from IPython.display import display, HTML

# Multiple Linear Regression with lagged auxiliary salinity
for i in range(-5, 6):
    if i == 0:
        df_lagged = df
    else:
        df_lagged = dataframes[i]
    print('-' * 100)
    display(HTML(f'<span style="font-size:20px; font-weight:bold;">Regression with lagged supplementary salinity {i} months:</span>'))
    X = df_lagged[['sst', 'sup_salinity']]
    y = df_lagged['d18O']
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)
    X_scaled = sm.add_constant(X_scaled)
    model = sm.OLS(y, X_scaled).fit()
    print(model.summary())

    X_sst = sm.add_constant(df['sst'])
    model_sst = sm.OLS(df['d18O'], X_sst).fit()
    print("R² for SST only:", model_sst.rsquared)

    X_salinity = sm.add_constant(df_lagged['sup_salinity'])
    model_salinity = sm.OLS(df_lagged['d18O'], X_salinity).fit()
    print("R² for Salinity only:", model_salinity.rsquared)

    # Visualize
    fig, axs = plt.subplots(1, 2, figsize=(12, 5))

    axs[0].scatter(df['sst'], df['d18O'], color='blue')
    sns.regplot(x='sst', y='d18O', data=df, scatter=False, ax=axs[0], color='blue', line_kws={'label': 'Best Fit Line'})
    axs[0].legend()
    axs[0].set_title("SST vs d18O")
    axs[0].set_xlabel("SST")
    axs[0].set_ylabel("d18O")

    axs[1].scatter(df_lagged['sup_salinity'], df_lagged['d18O'], color='green')
    sns.regplot(x='sup_salinity', y='d18O', data=df_lagged, scatter=False, ax=axs[1], color='green', line_kws={'label': 'Best Fit Line'})
    axs[1].set_title("Supplementary Salinity vs d18O")
    axs[1].set_xlabel("Supplementary Salinity")
    axs[1].set_ylabel("d18O")

    plt.tight_layout()
    plt.show()
# Out:
# ----------------------------------------------------------------------------------------------------
# <span style="font-size:20px; font-weight:bold;">Regression with lagged supplementary salinity -4 months:</span>
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   d18O   R-squared:                       0.526
# Model:                            OLS   Adj. R-squared:                  0.517
# Method:                 Least Squares   F-statistic:                     59.81
# Date:                Tue, 15 Jul 2025   Prob (F-statistic):           3.27e-18
# Time:                        15:33:35   Log-Likelihood:                 10.255
# No. Observations:                 111   AIC:                            -14.51
# Df Residuals:                     108   BIC:                            -6.381
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.7806      0.021   -178.089      0.000      -3.823      -3.739
# x1            -0.2429      0.024    -10.150      0.000      -0.290      -0.195
# x2            -0.0256      0.024     -1.068      0.288      -0.073       0.022
# ==============================================================================
# Omnibus:                        0.375   Durbin-Watson:                   0.561
# Prob(Omnibus):                  0.829   Jarque-Bera (JB):                0.326
# Skew:                           0.129   Prob(JB):                        0.850
# Kurtosis:                       2.942   Cond. No.                         1.65
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R² for SST only: 0.5037979808299236
# R² for Salinity only: 0.07295243470868529
# /var/folders/8v/z7_lynrn24bbpwy6p36j3cwc0000gn/T/ipykernel_54132/1117450400.py:32: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[0].legend()
# ----------------------------------------------------------------------------------------------------
# <span style="font-size:20px; font-weight:bold;">Regression with lagged supplementary salinity -3 months:</span>
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   d18O   R-squared:                       0.520
# Model:                            OLS   Adj. R-squared:                  0.511
# Method:                 Least Squares   F-statistic:                     59.05
# Date:                Tue, 15 Jul 2025   Prob (F-statistic):           4.22e-18
# Time:                        15:33:36   Log-Likelihood:                 10.023
# No. Observations:                 112   AIC:                            -14.05
# Df Residuals:                     109   BIC:                            -5.891
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.7824      0.021   -178.476      0.000      -3.824      -3.740
# x1            -0.2368      0.023    -10.083      0.000      -0.283      -0.190
# x2            -0.0161      0.023     -0.687      0.494      -0.063       0.030
# ==============================================================================
# Omnibus:                        0.274   Durbin-Watson:                   0.556
# Prob(Omnibus):                  0.872   Jarque-Bera (JB):                0.279
# Skew:                           0.113   Prob(JB):                        0.870
# Kurtosis:                       2.908   Cond. No.                         1.59
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R² for SST only: 0.5037979808299236
# R² for Salinity only: 0.0723607272513056
# /var/folders/8v/z7_lynrn24bbpwy6p36j3cwc0000gn/T/ipykernel_54132/1117450400.py:32: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[0].legend()
# ----------------------------------------------------------------------------------------------------
# <span style="font-size:20px; font-weight:bold;">Regression with lagged supplementary salinity -2 months:</span>
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   d18O   R-squared:                       0.510
# Model:                            OLS   Adj. R-squared:                  0.501
# Method:                 Least Squares   F-statistic:                     57.25
# Date:                Tue, 15 Jul 2025   Prob (F-statistic):           9.12e-18
# Time:                        15:33:36   Log-Likelihood:                 9.3423
# No. Observations:                 113   AIC:                            -12.68
# Df Residuals:                     110   BIC:                            -4.502
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.7836      0.021   -178.135      0.000      -3.826      -3.742
# x1            -0.2259      0.022    -10.165      0.000      -0.270      -0.182
# x2             0.0047      0.022      0.210      0.834      -0.039       0.049
# ==============================================================================
# Omnibus:                        0.105   Durbin-Watson:                   0.545
# Prob(Omnibus):                  0.949   Jarque-Bera (JB):                0.242
# Skew:                           0.057   Prob(JB):                        0.886
# Kurtosis:                       2.804   Cond. No.                         1.35
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R² for SST only: 0.5037979808299236
# R² for Salinity only: 0.04979064426470148
# /var/folders/8v/z7_lynrn24bbpwy6p36j3cwc0000gn/T/ipykernel_54132/1117450400.py:32: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[0].legend()
# ----------------------------------------------------------------------------------------------------
# <span style="font-size:20px; font-weight:bold;">Regression with lagged supplementary salinity -1 months:</span>
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   d18O   R-squared:                       0.512
# Model:                            OLS   Adj. R-squared:                  0.503
# Method:                 Least Squares   F-statistic:                     58.17
# Date:                Tue, 15 Jul 2025   Prob (F-statistic):           5.24e-18
# Time:                        15:33:36   Log-Likelihood:                 10.114
# No. Observations:                 114   AIC:                            -14.23
# Df Residuals:                     111   BIC:                            -6.020
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.7832      0.021   -180.005      0.000      -3.825      -3.742
# x1            -0.2213      0.021    -10.461      0.000      -0.263      -0.179
# x2             0.0297      0.021      1.405      0.163      -0.012       0.072
# ==============================================================================
# Omnibus:                        0.284   Durbin-Watson:                   0.529
# Prob(Omnibus):                  0.868   Jarque-Bera (JB):                0.458
# Skew:                           0.020   Prob(JB):                        0.795
# Kurtosis:                       2.692   Cond. No.                         1.12
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R² for SST only: 0.5037979808299236
# R² for Salinity only: 0.030402988379510165
# /var/folders/8v/z7_lynrn24bbpwy6p36j3cwc0000gn/T/ipykernel_54132/1117450400.py:32: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[0].legend()
# ----------------------------------------------------------------------------------------------------
# <span style="font-size:20px; font-weight:bold;">Regression with lagged supplementary salinity 0 months:</span>
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   d18O   R-squared:                       0.513
# Model:                            OLS   Adj. R-squared:                  0.504
# Method:                 Least Squares   F-statistic:                     58.96
# Date:                Tue, 15 Jul 2025   Prob (F-statistic):           3.23e-18
# Time:                        15:33:36   Log-Likelihood:                 10.530
# No. Observations:                 115   AIC:                            -15.06
# Df Residuals:                     112   BIC:                            -6.824
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.7810      0.021   -181.225      0.000      -3.822      -3.740
# x1            -0.2277      0.021    -10.854      0.000      -0.269      -0.186
# x2             0.0303      0.021      1.443      0.152      -0.011       0.072
# ==============================================================================
# Omnibus:                        0.164   Durbin-Watson:                   0.549
# Prob(Omnibus):                  0.921   Jarque-Bera (JB):                0.295
# Skew:                           0.077   Prob(JB):                        0.863
# Kurtosis:                       2.805   Cond. No.                         1.11
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R² for SST only: 0.5037979808299236
# R² for Salinity only: 0.000464800201296911
# /var/folders/8v/z7_lynrn24bbpwy6p36j3cwc0000gn/T/ipykernel_54132/1117450400.py:32: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[0].legend()
# ----------------------------------------------------------------------------------------------------
# <span style="font-size:20px; font-weight:bold;">Regression with lagged supplementary salinity 1 months:</span>
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   d18O   R-squared:                       0.509
# Model:                            OLS   Adj. R-squared:                  0.500
# Method:                 Least Squares   F-statistic:                     57.95
# Date:                Tue, 15 Jul 2025   Prob (F-statistic):           5.27e-18
# Time:                        15:33:37   Log-Likelihood:                 10.026
# No. Observations:                 115   AIC:                            -14.05
# Df Residuals:                     112   BIC:                            -5.817
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.7810      0.021   -180.433      0.000      -3.823      -3.739
# x1            -0.2328      0.022    -10.387      0.000      -0.277      -0.188
# x2             0.0234      0.022      1.043      0.299      -0.021       0.068
# ==============================================================================
# Omnibus:                        0.298   Durbin-Watson:                   0.555
# Prob(Omnibus):                  0.862   Jarque-Bera (JB):                0.409
# Skew:                           0.112   Prob(JB):                        0.815
# Kurtosis:                       2.812   Cond. No.                         1.45
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R² for SST only: 0.5037979808299236
# R² for Salinity only: 0.03516982314908179
# /var/folders/8v/z7_lynrn24bbpwy6p36j3cwc0000gn/T/ipykernel_54132/1117450400.py:32: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[0].legend()
# ----------------------------------------------------------------------------------------------------
# <span style="font-size:20px; font-weight:bold;">Regression with lagged supplementary salinity 2 months:</span>
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   d18O   R-squared:                       0.505
# Model:                            OLS   Adj. R-squared:                  0.496
# Method:                 Least Squares   F-statistic:                     57.17
# Date:                Tue, 15 Jul 2025   Prob (F-statistic):           7.74e-18
# Time:                        15:33:37   Log-Likelihood:                 9.6307
# No. Observations:                 115   AIC:                            -13.26
# Df Residuals:                     112   BIC:                            -5.027
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.7810      0.021   -179.814      0.000      -3.823      -3.739
# x1            -0.2318      0.025     -9.398      0.000      -0.281      -0.183
# x2             0.0138      0.025      0.560      0.577      -0.035       0.063
# ==============================================================================
# Omnibus:                        0.371   Durbin-Watson:                   0.543
# Prob(Omnibus):                  0.831   Jarque-Bera (JB):                0.495
# Skew:                           0.121   Prob(JB):                        0.781
# Kurtosis:                       2.789   Cond. No.                         1.79
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R² for SST only: 0.5037979808299236
# R² for Salinity only: 0.11494983319617724
# /var/folders/8v/z7_lynrn24bbpwy6p36j3cwc0000gn/T/ipykernel_54132/1117450400.py:32: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[0].legend()
# ----------------------------------------------------------------------------------------------------
# <span style="font-size:20px; font-weight:bold;">Regression with lagged supplementary salinity 3 months:</span>
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   d18O   R-squared:                       0.504
# Model:                            OLS   Adj. R-squared:                  0.495
# Method:                 Least Squares   F-statistic:                     56.86
# Date:                Tue, 15 Jul 2025   Prob (F-statistic):           9.03e-18
# Time:                        15:33:37   Log-Likelihood:                 9.4724
# No. Observations:                 115   AIC:                            -12.94
# Df Residuals:                     112   BIC:                            -4.710
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.7810      0.021   -179.566      0.000      -3.823      -3.739
# x1            -0.2237      0.025     -9.096      0.000      -0.272      -0.175
# x2            -0.0017      0.025     -0.067      0.946      -0.050       0.047
# ==============================================================================
# Omnibus:                        0.362   Durbin-Watson:                   0.534
# Prob(Omnibus):                  0.834   Jarque-Bera (JB):                0.513
# Skew:                           0.105   Prob(JB):                        0.774
# Kurtosis:                       2.750   Cond. No.                         1.77
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /var/folders/8v/z7_lynrn24bbpwy6p36j3cwc0000gn/T/ipykernel_54132/1117450400.py:32: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[0].legend()
# R² for SST only: 0.5037979808299236
# R² for Salinity only: 0.13723933144908695
# ----------------------------------------------------------------------------------------------------
# <span style="font-size:20px; font-weight:bold;">Regression with lagged supplementary salinity 4 months:</span>
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   d18O   R-squared:                       0.504
# Model:                            OLS   Adj. R-squared:                  0.495
# Method:                 Least Squares   F-statistic:                     56.86
# Date:                Tue, 15 Jul 2025   Prob (F-statistic):           9.05e-18
# Time:                        15:33:37   Log-Likelihood:                 9.4702
# No. Observations:                 115   AIC:                            -12.94
# Df Residuals:                     112   BIC:                            -4.706
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.7810      0.021   -179.563      0.000      -3.823      -3.739
# x1            -0.2244      0.023     -9.747      0.000      -0.270      -0.179
# x2            -0.0004      0.023     -0.017      0.987      -0.046       0.045
# ==============================================================================
# Omnibus:                        0.371   Durbin-Watson:                   0.534
# Prob(Omnibus):                  0.831   Jarque-Bera (JB):                0.522
# Skew:                           0.106   Prob(JB):                        0.770
# Kurtosis:                       2.746   Cond. No.                         1.54
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R² for SST only: 0.5037979808299236
# R² for Salinity only: 0.08291044919599677
# /var/folders/8v/z7_lynrn24bbpwy6p36j3cwc0000gn/T/ipykernel_54132/1117450400.py:32: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[0].legend()
