# %% [markdown]
# # Topography of the Red Sea
#
# Pulled from [GEBCO](https://www.gebco.net/data-products/gridded-bathymetry-data#area).

# %%
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %%
# Load GEBCO dataset
gebco = xr.open_dataset("gebco_2024_n30.0_s10.0_w30.0_e45.0.nc") 
print(gebco.data_vars)
# Out:
# Data variables:
#     elevation  (lat, lon) int16 35MB ...

# %%
topo = gebco['elevation']

# %%
fig = plt.figure(figsize=(10, 6))
ax = plt.axes(projection=ccrs.PlateCarree())

topo.plot(
    ax=ax,
    transform=ccrs.PlateCarree(),
    cmap='terrain',
    cbar_kwargs={'label': 'Elevation (m)'}
)

ax.set_extent([30, 45, 10, 30], crs=ccrs.PlateCarree())
ax.coastlines(resolution='10m')
ax.add_feature(cfeature.BORDERS)
ax.set_title("Topography of the Red Sea Region - from GEBCO")

plt.show()

# Save the figure
fig.savefig("plots/gebco_red_sea_topography.png", dpi=300, bbox_inches='tight')
